# %%
import pandas as pd

# %%
df = pd.read_excel("E:\Data Science\Datasets\Attribute DataSet.xlsx" )

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel("E:\Data Science\Datasets\Attribute DataSet.xlsx", sheet_name = 'Data2'  , names = ["Animi2", "DayEnd"])
# Out:
#    Animi2 DayEnd
# 0       1    Mon
# 1       2    Tue
# 2       3    wed
# 3       4    Thu
# 4       5    Fri
# 5       6    Sat
# 6       7    Sun
# 7       8    Mon

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df1 = pd.read_csv("E:\Data Science\Datasets\haberman.csv",names = ["age" , "year of operation"  , "Postive Auxiliary nodes detected" , "Survival status"])

# %%
df1
# Out:
#      age  year of operation  Postive Auxiliary nodes detected  Survival status
# 0     30                 64                                 1                1
# 1     30                 62                                 3                1
# 2     30                 65                                 0                1
# 3     31                 59                                 2                1
# 4     31                 65                                 4                1
# ..   ...                ...                               ...              ...
# 301   75                 62                                 1                1
# 302   76                 67                                 0                1
# 303   77                 65                                 3                1
# 304   78                 65                                 1                2
# 305   83                 58                                 2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/LetterRecognition.csv")
# Out:
#       lettr  x.box  y.box  width  high  onpix  x.bar  y.bar  x2bar  y2bar  \
# 0         T      2      8      3     5      1      8     13      0      6
# 1         I      5     12      3     7      2     10      5      5      4
# 2         D      4     11      6     8      6     10      6      2      6
# 3         N      7     11      6     6      3      5      9      4      6
# 4         G      2      1      3     1      1      8      6      6      6
# ...     ...    ...    ...    ...   ...    ...    ...    ...    ...    ...
# 19995     D      2      2      3     3      2      7      7      7      6
# 19996     C      7     10      8     8      4      4      8      6      9
# 19997     T      6      9      6     7      5      6     11      3      7
# 19998     S      2      3      4     2      1      8      7      2      6
# 19999     A      4      9      6     6      2      9      5      3      1
#
#        xybar  x2ybr  xy2br  x.ege  xegvy  y.ege  yegvx
# ...

# %%
a = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
j = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
j.head(2)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0  https://github.com/pandas-dev/pandas/issues/49111  1409999720
# ...

# %%
j.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
j["user"][9]
# Out:
# {'login': 'vamsi-verma-s',
#  'id': 40605798,
#  'node_id': 'MDQ6VXNlcjQwNjA1Nzk4',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/40605798?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/vamsi-verma-s',
#  'html_url': 'https://github.com/vamsi-verma-s',
#  'followers_url': 'https://api.github.com/users/vamsi-verma-s/followers',
#  'following_url': 'https://api.github.com/users/vamsi-verma-s/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/vamsi-verma-s/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/vamsi-verma-s/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/vamsi-verma-s/subscriptions',
#  'organizations_url': 'https://api.github.com/users/vamsi-verma-s/orgs',
#  'repos_url': 'https://api.github.com/users/vamsi-verma-s/repos',
#  'events_url': 'https://api.github.com/users/vamsi-verma-s/events{/privacy}',
# ...

# %%
df.head(5)
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.to_json("exjson.json")

# %%
pwd
# Out:
# 'C:\\Users\\Dell'

# %%
ap = pd.read_csv("E:\Data Science\Datasets\sales_data_final.csv")

# %%
ap.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
#
# [2 rows x 21 columns]

# %%
ap
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
ap.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
type(ap["state"])
# Out:
# pandas.core.series.Series

# %%
ap.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
type(ap[['order_id', 'order_date', 'ship_date']])
# Out:
# pandas.core.frame.DataFrame

# %%
ap.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
ap.dtypes == 'object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
ap[ap.dtypes[ ap.dtypes =='object'] .index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
ap[ap.dtypes[ap.dtypes == 'float'].index].describe()
# Out:
#            discount        profit  shipping_cost
# count  51290.000000  51290.000000   51290.000000
# mean       0.142908     28.641740      26.375915
# std        0.212280    174.424113      57.296804
# min        0.000000  -6599.978000       0.000000
# 25%        0.000000      0.000000       2.610000
# 50%        0.000000      9.240000       7.790000
# 75%        0.200000     36.810000      24.450000
# max        0.850000   8399.976000     933.570000

# %%
ap['order_id'][1:41:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
ap
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
ap['name']='sumanth'

# %%
ap['name'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: name, Length: 51290, dtype: bool

# %%
ap.isnull()
# Out:
#        order_id  order_date  ship_date  ship_mode  customer_name  segment  \
# 0         False       False      False      False          False    False
# 1         False       False      False      False          False    False
# 2         False       False      False      False          False    False
# 3         False       False      False      False          False    False
# 4         False       False      False      False          False    False
# ...         ...         ...        ...        ...            ...      ...
# 51285     False       False      False      False          False    False
# 51286     False       False      False      False          False    False
# 51287     False       False      False      False          False    False
# 51288     False       False      False      False          False    False
# 51289     False       False      False      False          False    False
#
#        state  country  market  region  ...  sub_category  product_name  sales  \
# ...

# %%
ap.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'name'],
#       dtype='object')

# %%
ap[ap['profit'] == max(ap['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
ap[ap['country'] == 'Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %%
ap[ap['shipping_cost'] > 80]['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
ap[(ap['shipping_cost'] > 100) & (ap['profit'] < 10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040        2015  1/6/2011  Standard Class
# 1        IN-2011-47883        2015  1/8/2011  Standard Class
# 2         HU-2011-1220        2015  1/5/2011    Second Class
# 3      IT-2011-3647632        2015  1/5/2011    Second Class
# 4        IN-2011-47883        2015  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427        2015  1/4/2015  Standard Class
# 51286     MO-2014-2560        2015  1/5/2015  Standard Class
# 51287   MX-2014-110527        2015  1/2/2015    Second Class
# 51288   MX-2014-114783        2015  1/6/2015  Standard Class
# 51289   CA-2014-156720        2015  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
date = pd.to_datetime(ap["order_date"])

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
ap['coverteddate'] = pd.to_datetime(ap["order_date"])

# %%
ap.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ... sub_category  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
#
#                product_name sales quantity discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408        2      0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120        3      0.1   36.036           9.72
#
#    order_priority  year coverteddate
# 0          Medium  2011   2011-01-01
# 1          Medium  2011   2011-01-01
#
# [2 rows x 22 columns]

# %%
ap['order_date_year'] = ap['coverteddate'].dt.year

# %%
ap.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#                product_name sales quantity discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408        2      0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120        3      0.1   36.036           9.72
#
#    order_priority  year  coverteddate order_date_year
# 0          Medium  2011    2011-01-01            2011
# 1          Medium  2011    2011-01-01            2011
#
# [2 rows x 23 columns]

# %%
ap['order_date_month'] = ap['coverteddate'].dt.month

# %%
ap.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ... sales quantity  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...   408        2
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...   120        3
#
#   discount   profit shipping_cost  order_priority  year  coverteddate  \
# 0      0.0  106.140         35.46          Medium  2011    2011-01-01
# 1      0.1   36.036          9.72          Medium  2011    2011-01-01
#
#    order_date_year order_date_month
# 0             2011                1
# 1             2011                1
#
# [2 rows x 24 columns]

# %%
ap[ap['order_date_year'] == 2014].tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ... sales  \
# 51285  Corporate        California  United States      US     West  ...    14
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...     4
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...    26
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...     7
# 51289   Consumer          Colorado  United States      US     West  ...     3
#
# ...

# %%
ap['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
ap["cost2company"] = ap['shipping_cost']+ap['discount']

# %%
ap[ap["cost2company"] == max(ap["cost2company"])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
ap.drop("coverteddate" , axis = 1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
ap
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
ap.loc[0:5]
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
# ...

# %%
ap.loc[0:4, ['order_id','order_date','ship_date']]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 1    IN-2011-47883   1/1/2011  1/8/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
ap.iloc[0:4, 0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 1    IN-2011-47883   1/1/2011  1/8/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011

# %%
ap
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
ap.iloc[2:6,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
ap1 = ap[ap.dtypes[(ap.dtypes == 'float64') | (ap.dtypes =='int64')].index]

# %%
ap2 = ap1[ap1>100]

# %%
ap2
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 1           NaN       NaN     NaN            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  cost2company
# 0                   NaN           NaN
# ...

# %%
ap2.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, order_date_month, cost2company]
# Index: []

# %%
ap2.dropna(axis=1)
# Out:
#        year  order_date_year
# 0      2011             2011
# 1      2011             2011
# 2      2011             2011
# 3      2011             2011
# 4      2011             2011
# ...     ...              ...
# 51285  2014             2014
# 51286  2014             2014
# 51287  2014             2014
# 51288  2014             2014
# 51289  2014             2014
#
# [51290 rows x 2 columns]

# %%
ap2
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 1           NaN       NaN     NaN            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  cost2company
# 0                   NaN           NaN
# ...

# %%
ap2.dropna(thresh=2)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 1           NaN       NaN     NaN            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  cost2company
# 0                   NaN           NaN
# ...

# %%
ap2.dropna(thresh=, axis=1)
# Out:
#        profit  shipping_cost  year  order_date_year  cost2company
# 0      106.14            NaN  2011             2011           NaN
# 1         NaN            NaN  2011             2011           NaN
# 2         NaN            NaN  2011             2011           NaN
# 3         NaN            NaN  2011             2011           NaN
# 4         NaN            NaN  2011             2011           NaN
# ...       ...            ...   ...              ...           ...
# 51285     NaN            NaN  2014             2014           NaN
# 51286     NaN            NaN  2014             2014           NaN
# 51287     NaN            NaN  2014             2014           NaN
# 51288     NaN            NaN  2014             2014           NaN
# 51289     NaN            NaN  2014             2014           NaN
#
# [51290 rows x 5 columns]

# %%
ap2.fillna(value=2)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           2.0       2.0  106.14            2.0  2011             2011
# 1           2.0       2.0    2.00            2.0  2011             2011
# 2           2.0       2.0    2.00            2.0  2011             2011
# 3           2.0       2.0    2.00            2.0  2011             2011
# 4           2.0       2.0    2.00            2.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       2.0       2.0    2.00            2.0  2014             2014
# 51286       2.0       2.0    2.00            2.0  2014             2014
# 51287       2.0       2.0    2.00            2.0  2014             2014
# 51288       2.0       2.0    2.00            2.0  2014             2014
# 51289       2.0       2.0    2.00            2.0  2014             2014
#
#        order_date_month  cost2company
# 0                   2.0           2.0
# ...

# %%
ap2.fillna(value = ap2['profit'].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 1      285.710477  285.710477  285.710477     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        order_date_year  order_date_month  cost2company
# 0                 2011        285.710477    285.710477
# 1                 2011        285.710477    285.710477
# ...

# %%
ap.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'coverteddate', 'order_date_year', 'order_date_month', 'cost2company'],
#       dtype='object')

# %%
ap.groupby('order_date_year')['discount'].mean()
# Out:
# order_date_year
# 2011    0.148188
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
ap.groupby('order_date_year')['shipping_cost'].mean()
# Out:
# order_date_year
# 2011    27.147264
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
ap[['country','market']]
# Out:
#              country  market
# 0            Algeria  Africa
# 1          Australia    APAC
# 2            Hungary    EMEA
# 3             Sweden      EU
# 4          Australia    APAC
# ...              ...     ...
# 51285  United States      US
# 51286        Morocco  Africa
# 51287      Nicaragua   LATAM
# 51288         Mexico   LATAM
# 51289  United States      US
#
# [51290 rows x 2 columns]

# %%
ap['sales'] = ap.sales.str.replace("," , "").astype(int)

# %%
ap['sales']
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: int32

# %%
ap.dtypes
# Out:
# order_id                    object
# order_date                  object
# ship_date                   object
# ship_mode                   object
# customer_name               object
# segment                     object
# state                       object
# country                     object
# market                      object
# region                      object
# product_id                  object
# category                    object
# sub_category                object
# product_name                object
# sales                        int32
# quantity                     int64
# discount                   float64
# profit                     float64
# shipping_cost              float64
# order_priority              object
# year                         int64
# coverteddate        datetime64[ns]
# order_date_year              int64
# order_date_month             int64
# cost2company               float64
# dtype: object

# %%
ap.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.112581
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
ap.groupby('order_date_year')['quantity'].mean()
# Out:
# order_date_year
# 2011    3.494443
# 2012    3.476647
# 2013    3.488369
# 2014    3.457989
# Name: quantity, dtype: float64

# %%
dataa = {'name' : ['sudh','krish','sumanth', 'naveen'],
         'salary' : [100,200,300,400],
         'email' : ['sum@gmail.com', 'sudh@gmail.com', 'krish@gmail.com', 'naveen@gmail.com'],
         'addr' : [ 'Del','Blr','Hyd','Vizag']
        }

# %%
data1 = pd.DataFrame(data)

# %%
data1.loc[5:6]
# Out:
# Empty DataFrame
# Columns: [name, salary, email, addr]
# Index: []

# %%
data1.iloc[1:3]
# Out:
#       name  salary            email addr
# 1    krish     200   sudh@gmail.com  Blr
# 2  sumanth     300  krish@gmail.com  Hyd

# %%
dat1 = { 'pf' : [123,345,234,456],
      'income_tax' : [374,4850,29484,330],
      'mobile_no' : [1234,3895,3848,28494],
      'courses' : ['ds','bigdata', 'webdev','blockchain']
     }

# %%
data2=pd.DataFrame(dat1)

# %%
data2
# Out:
#     pf  income_tax  mobile_no     courses
# 0  123         374       1234          ds
# 1  345        4850       3895     bigdata
# 2  234       29484       3848      webdev
# 3  456         330      28494  blockchain

# %%
data1
# Out:
#       name  salary             email   addr
# 0     sudh     100     sum@gmail.com    Del
# 1    krish     200    sudh@gmail.com    Blr
# 2  sumanth     300   krish@gmail.com    Hyd
# 3   naveen     400  naveen@gmail.com  Vizag

# %%
pd.concat([data1,data2] , axis=1)
# Out:
#       name  salary             email   addr   pf  income_tax  mobile_no  \
# 0     sudh     100     sum@gmail.com    Del  123         374       1234
# 1    krish     200    sudh@gmail.com    Blr  345        4850       3895
# 2  sumanth     300   krish@gmail.com    Hyd  234       29484       3848
# 3   naveen     400  naveen@gmail.com  Vizag  456         330      28494
#
#       courses
# 0          ds
# 1     bigdata
# 2      webdev
# 3  blockchain

# %%
da1 = { '0' : [123,345,234,456],
      '1' : [374,4850,29484,330],
      '2' : [1234,3895,3848,28494],
      '3' : ['ds','bigdata', 'webdev','blockchain']
     }

# %%
da2 = {'0' : ['sudh','krish','sumanth', 'naveen'],
         '1' : [100,200,300,400],
         '2' : ['sum@gmail.com', 'sudh@gmail.com', 'krish@gmail.com', 'naveen@gmail.com'],
         '3' : [ 'Del','Blr','Hyd','Vizag']
        }

# %%
df1 = pd.DataFrame(da1)

# %%
df2 = pd.DataFrame(da2)

# %%
pd.concat([df2,df1])
# Out:
#          0      1                 2           3
# 0     sudh    100     sum@gmail.com         Del
# 1    krish    200    sudh@gmail.com         Blr
# 2  sumanth    300   krish@gmail.com         Hyd
# 3   naveen    400  naveen@gmail.com       Vizag
# 0      123    374              1234          ds
# 1      345   4850              3895     bigdata
# 2      234  29484              3848      webdev
# 3      456    330             28494  blockchain

# %%
daa1 = {'empid' : [ 101,102,103,104],
        'salary' : [123,234,234,564],
        'pf': [123,234,567,678]
       }

# %%
daa2 = { 'empid' : [ 101,102,103,104],
        'mobno' : [123,33345,234,1233],
        'hou' : [122,472,283,362]
}

# %%
data3=pd.DataFrame(daa1)

# %%
data4=pd.DataFrame(daa2)

# %%
data3
# Out:
#    empid  salary   pf
# 0    101     123  123
# 1    102     234  234
# 2    103     234  567
# 3    104     564  678

# %%
data4
# Out:
#    empid  mobno  hou
# 0    101    123  122
# 1    102  33345  472
# 2    103    234  283
# 3    104   1233  362

# %%
pd.merge(data3,data4)
# Out:
#    empid  salary   pf  mobno  hou
# 0    101     123  123    123  122
# 1    102     234  234  33345  472
# 2    103     234  567    234  283
# 3    104     564  678   1233  362

# %%
daaa1 = {'empid1' : [ 101,102,103,104],
        'salary' : [123,234,234,564],
        'pf': [123,234,567,678]
       }

# %%
daaa2 = { 'empid' : [ 101,102,103,104],
        'mobno' : [123,33345,234,1233],
        'hou' : [122,472,283,362]
}

# %%
dataa3=pd.DataFrame(daaa1)

# %%
dataa4=pd.DataFrame(daaa2)

# %%
pd.merge(dataa3,dataa4, left_on= 'empid1', right_on = 'empid' )
# Out:
#    empid1  salary   pf  empid  mobno  hou
# 0     101     123  123    101    123  122
# 1     102     234  234    102  33345  472
# 2     103     234  567    103    234  283
# 3     104     564  678    104   1233  362

# %%
daaaa1 = {'empid1' : [ 101,102,103,104],
        'salary1' : [123,234,234,564],
        'pf': [123,234,567,678]
       }

# %%
daaaa2 = { 'empid2' : [ 101,102,103,104],
        'salary2' : [123,33345,234,1233],
        'hou' : [122,472,283,362]
}

# %%
data5= pd.DataFrame(daaaa1, index = ['a','b','c','d'] )

# %%
data6= pd.DataFrame(daaaa2, index = ['a','b','c','d'])

# %%
data5
# Out:
#    empid1  salary1   pf
# a     101      123  123
# b     102      234  234
# c     103      234  567
# d     104      564  678

# %%
data6
# Out:
#    empid2  salary2  hou
# a     101      123  122
# b     102    33345  472
# c     103      234  283
# d     104     1233  362

# %%
data5.join(data6)
# Out:
#    empid1  salary1   pf  empid2  salary2  hou
# a     101      123  123     101      123  122
# b     102      234  234     102    33345  472
# c     103      234  567     103      234  283
# d     104      564  678     104     1233  362

# %%
ap.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ... quantity  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...        3
#
#   discount   profit shipping_cost  order_priority  year  coverteddate  \
# 0      0.0  106.140         35.46          Medium  2011    2011-01-01
# 1      0.1   36.036          9.72          Medium  2011    2011-01-01
#
#    order_date_year  order_date_month cost2company
# 0             2011                 1        35.46
# 1             2011                 1         9.82
#
# [2 rows x 25 columns]

# %%
def profit_flag(a):
    if a>0:
        return 'positive'
    else:
        return "negative"

# %%
profit_flag(-3)
# Out:
# 'negative'

# %%
profit_flag(4)
# Out:
# 'positive'

# %%
ap["sales_profit"] = ap["profit"].apply(profit_flag)

# %%
ap.head(5)
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  coverteddate  order_date_year  \
# ...

# %%
ap['len_of_customername'] = ap["customer_name"].apply(len)

# %%
ap.head(5)
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
#   shipping_cost order_priority  year  coverteddate  order_date_year  \
# ...

# %%
def quantity_flag(a):
    if a<10 :
        return "low"
    elif a>10 and a<20:
        return "medium"
    else:
        return "high"

# %%
ap["flag_quantity"] = ap["quantity"].apply(quantity_flag)

# %%
ap.tail(10)
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 51280    TZ-2014-8220  12/31/2014  1/6/2015  Standard Class
# 51281  CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51282    UP-2014-4410  12/31/2014  1/4/2015  Standard Class
# 51283   IN-2014-23754  12/31/2014  1/7/2015  Standard Class
# 51284  MX-2014-108574  12/31/2014  1/4/2015  Standard Class
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#             customer_name      segment             state        country  \
# 51280  Christine Kargatis  Home Office     Dar Es Salaam       Tanzania
# 51281          Erica Bern    Corporate        California  United States
# 51282        Guy Thornton     Consumer      Zaporizhzhya        Ukraine
# ...

# %%
ap["sq_quantity"]= ap["quantity"].apply(lambda a: a**2)

# %%
ap.head(5)
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   order_priority  year coverteddate order_date_year  order_date_month  \
# ...

# %%
import numpy as np

# %%
np.array([12,3,4,5])
# Out:
# array([12,  3,  4,  5])

# %%
type(np.array([12,3,4,5]))
# Out:
# numpy.ndarray

# %%
np.array([[1,2,3,4],[5,6,7,8]])
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
l=[[0,1,2,3],[1,2,3,4]]

# %%
l[0][1]
# Out:
# 1

# %%
 b = np.array([2,3,4,5],ndmin=3)

# %%
type(b)
# Out:
# numpy.ndarray

# %%
arr = np.array([[1,2,3],[3,4,5],[5,6,7]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [5, 6, 7]])

# %%
arr.ndim
# Out:
# 2

# %%
np.random.randint(1,10,(4,4))
# Out:
# array([[8, 3, 2, 1],
#        [1, 9, 3, 8],
#        [7, 4, 3, 2],
#        [5, 6, 8, 6]])

# %%
np.random.randint(1,10,(4,4,2))
# Out:
# array([[[8, 3],
#         [5, 2],
#         [5, 6],
#         [3, 1]],
#
#        [[8, 9],
#         [6, 8],
#         [6, 8],
#         [2, 8]],
#
#        [[7, 3],
#         [7, 2],
#         [8, 2],
#         [2, 9]],
#
#        [[5, 5],
#         [3, 1],
#         [8, 4],
#         [2, 2]]])
